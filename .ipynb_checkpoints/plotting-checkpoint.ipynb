# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10*np.pi, 200)
y = np.exp(-0.1*x) * np.cos(x)

plt.title('Graphic', fontsize = 20)
plt.xlabel('x', fontsize = 15)
plt.ylabel('y', fontsize = 15)
plt.grid()
plt.plot(x, y, 'r--')
plt.show()
